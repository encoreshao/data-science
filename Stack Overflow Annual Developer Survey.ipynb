# %% [markdown]
# # Stack Overflow Annual Developer Survey
#
# 2020
#
# With nearly 65,000 responses fielded from over 180 countries and dependent territories, our 2020 Annual Developer Survey examines all aspects of the developer experience from career satisfaction and job search to education and opinions on open source software.
#
# - The stackoverflow 2020 survey data was obtained from https://insights.stackoverflow.com/survey/

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option("display.max_rows", 100)

# %%
# Read data from local
# df = pd.read_csv('resources/survey_results_public.csv'

# %%
# Derive the id from the google drive shareable link.
# For the file at hand the link is as below

def read_csv_from_drive(drive_id):
    survey_drive_url = 'https://drive.google.com/file/d/{}/view?usp=sharing'.format(drive_id)
    survey_csv_path = 'https://drive.google.com/uc?export=download&id=' + drive_url.split('/')[-2]
    # df = pd.read_pickle(path)
    return pd.read_csv(csv_path)

# %%
df = read_csv_from_drive('1XKFq-FwoIFRYTcns3qOrZ1pZdVq7bTun')
df.head()
# Out:
#    Respondent                                                MainBranch  \
# 0           1                            I am a developer by profession
# 1           2                            I am a developer by profession
# 2           3                               I code primarily as a hobby
# 3           4                            I am a developer by profession
# 4           5  I used to be a developer by profession, but no longer am
#
#   Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0      Yes   NaN         13  Monthly        NaN            NaN
# 1       No   NaN         19      NaN        NaN            NaN
# 2      Yes   NaN         15      NaN        NaN            NaN
# 3      Yes  25.0         18      NaN        NaN            NaN
# 4      Yes  31.0         16      NaN        NaN            NaN
#
#               Country    CurrencyDesc  ...                  SurveyEase  \
# 0             Germany   European Euro  ...  Neither easy nor difficult
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
# df_schema = pd.read_csv('resources/survey_results_schema.csv')

# %%
df_schema = read_csv_from_drive('1h7wyR0W4orcDkOq7Ba0j0QxML1_p62Ec')
df_schema.head()

# %%
df_schema
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df[df['Age'].notna()].Age.unique()
# Out:
# array([ 25. ,  31. ,  36. ,  30. ,  22. ,  23. ,  49. ,  53. ,  27. ,
#         45. ,  32. ,  24. ,  40. ,  18. ,  39. ,  29. ,  16. ,  34. ,
#         19. ,  35. ,  20. ,  38. ,  57. ,  28. ,  17. ,  44. ,  21. ,
#         48. ,  26. ,  42. ,  55. ,  37. ,  50. ,  41. ,  64. ,  63. ,
#         33. ,  43. ,  51. ,  60. ,  59. ,  62. ,  69. ,  52. ,  46. ,
#         49.5,  56. ,  47. ,  15. ,  72. ,  13. ,  71. ,  54. ,  70. ,
#         11. ,  14. ,  61. ,  26.8,  86. ,  58. ,  67. ,  94. ,  65. ,
#         66. ,  84. ,  73. ,  78. ,  68. ,  99. ,  74. ,  12. ,  77. ,
#         15.5,  85. ,  76. ,  35.7,  32.5,  81. ,  23.8,  97. ,  96. ,
#         26.5,   3. ,  24.5,  14.7,  34.5,   5. ,   1. ,  20.5,  79. ,
#        279. ,  22.5,  27.5,  32.8,  10. ,  89. ,  80. ,  98. ,  19.8,
#          7. ,  21.5,  31.5,  88. ,  39.5,  16.5,  75. ,  83. ,  23.4,
#         95. ,  14.5])

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %% [markdown]
# # Getting more value from the Pandas’ value_counts()

# %%
pie_hobbyist = pd.DataFrame(df['Hobbyist'].value_counts())
pie_hobbyist.columns=['Hobbyist']
pie_hobbyist.plot(kind='pie', y='Hobbyist', subplots=True, figsize=(15, 15))
# Out:
# array([<AxesSubplot:ylabel='Hobbyist'>], dtype=object)

# %%
countries = df.Country.unique()

# %%
len(countries)
# Out:
# 184

# %%
pie_country = pd.DataFrame(df['Country'].value_counts().head(10))
pie_country.columns=['Country']
pie_country.plot(kind='pie', y='Country', subplots=True, figsize=(15, 20))
# Out:
# array([<AxesSubplot:ylabel='Country'>], dtype=object)

# %%
df['WebframeDesireNextYear'].value_counts()
# Out:
# React.js                                                             2480
# ASP.NET Core                                                         1106
# Vue.js                                                               1079
# Spring                                                               1011
# Express;React.js                                                      899
#                                                                      ...
# ASP.NET;ASP.NET Core;Express;Laravel;React.js;Vue.js                    1
# ASP.NET;ASP.NET Core;jQuery;Laravel;Spring                              1
# Angular;ASP.NET;ASP.NET Core;jQuery;React.js;Ruby on Rails;Spring       1
# ASP.NET Core;Django;Express;Flask;React.js;Ruby on Rails;Vue.js         1
# Django;Gatsby;jQuery;React.js;Ruby on Rails                             1
# Name: WebframeDesireNextYear, Length: 3986, dtype: int64

# %%
skills = df[df.WebframeDesireNextYear.notna()].WebframeDesireNextYear.unique()

# %%
len(skills)
# Out:
# 3986

# %%
skills
# Out:
# array(['ASP.NET Core', 'Django;Ruby on Rails', 'React.js', ...,
#        'Django;Express;Flask;Gatsby;jQuery;Laravel;React.js;Ruby on Rails;Spring;Vue.js',
#        'ASP.NET;ASP.NET Core;Flask;Gatsby;jQuery;React.js;Vue.js',
#        'Drupal;Flask;Gatsby;Spring;Vue.js'], dtype=object)

# %%
# df.WebframeDesireNextYear.mode()

df['WebframeDesireNextYear'].value_counts().head(100)
# Out:
# React.js                                2480
# ASP.NET Core                            1106
# Vue.js                                  1079
# Spring                                  1011
# Express;React.js                         899
#                                         ...
# Flask;Spring                              60
# Angular;Express;Vue.js                    60
# Angular;Angular.js;jQuery;React.js        60
# ASP.NET;ASP.NET Core;React.js;Vue.js      59
# Angular;Angular.js;jQuery                 58
# Name: WebframeDesireNextYear, Length: 100, dtype: int64

# %%
pie_webframe_desire_next_year = pd.DataFrame(df['WebframeDesireNextYear'].value_counts().head(10))
pie_webframe_desire_next_year.columns=['WebframeDesireNextYear']
pie_webframe_desire_next_year.plot(kind='pie', y='WebframeDesireNextYear', subplots=True, figsize=(15, 15))
# Out:
# array([<AxesSubplot:ylabel='WebframeDesireNextYear'>], dtype=object)

# %%
pie_webframe_worked_with = pd.DataFrame(df['WebframeWorkedWith'].value_counts().head(10))
pie_webframe_worked_with.columns=['WebframeWorkedWith']
pie_webframe_worked_with.plot(kind='pie', y='WebframeWorkedWith', subplots=True, figsize=(15, 15))
# Out:
# array([<AxesSubplot:ylabel='WebframeWorkedWith'>], dtype=object)

# %%
df['Gender'].value_counts().head(10)

# pie_gender = pd.DataFrame(df['Gender'].value_counts().head(10))
# pie_gender.columns=['Gender']
# pie_gender.plot(kind='pie', y='Gender', subplots=True, figsize=(15, 15))
# Out:
# Man                                                            46013
# Woman                                                           3844
# Non-binary, genderqueer, or gender non-conforming                385
# Man;Non-binary, genderqueer, or gender non-conforming            121
# Woman;Non-binary, genderqueer, or gender non-conforming           92
# Woman;Man                                                         76
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       26
# Name: Gender, dtype: int64
